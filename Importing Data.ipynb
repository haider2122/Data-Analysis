# %%
with open('titanic.csv') as f:
    text = f.readlines()

# %%
text
# Out:
# ['survived,pclass,sex,age,sibsp,parch,fare,embarked,deck\n',
#  '0,3,male,22.0,1,0,7.25,S,\n',
#  '1,1,female,38.0,1,0,71.2833,C,C\n',
#  '1,3,female,26.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,53.1,S,C\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.4583,Q,\n',
#  '0,1,male,54.0,0,0,51.8625,S,E\n',
#  '0,3,male,2.0,3,1,21.075,S,\n',
#  '1,3,female,27.0,0,2,11.1333,S,\n',
#  '1,2,female,14.0,1,0,30.0708,C,\n',
#  '1,3,female,4.0,1,1,16.7,S,G\n',
#  '1,1,female,58.0,0,0,26.55,S,C\n',
#  '0,3,male,20.0,0,0,8.05,S,\n',
#  '0,3,male,39.0,1,5,31.275,S,\n',
#  '0,3,female,14.0,0,0,7.8542,S,\n',
#  '1,2,female,55.0,0,0,16.0,S,\n',
#  '0,3,male,2.0,4,1,29.125,Q,\n',
#  '1,2,male,,0,0,13.0,S,\n',
#  '0,3,female,31.0,1,0,18.0,S,\n',
#  '1,3,female,,0,0,7.225,C,\n',
#  '0,2,male,35.0,0,0,26.0,S,\n',
#  '1,2,male,34.0,0,0,13.0,S,D\n',
#  '1,3,female,15.0,0,0,8.0292,Q,\n',
#  '1,1,male,28.0,0,0,35.5,S,A\n',
#  '0,3,female,8.0,3,1,21.075,S,\n',
#  '1,3,female,38.0,1,5,31.3875,S,\n',
# ...

# %%
len(text)
#The csv file here is read in form of a list
# Out:
# 892

# %%
import pandas as pd
pd.read_csv('titanic.csv').head() #Here the following list/csv format is changed to tabular
#Methods associated with read_csv method
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
pd.read_csv('titanic.csv',index_col='pclass').head()
# Out:
#         survived     sex   age  sibsp  parch     fare embarked deck
# pclass
# 3              0    male  22.0      1      0   7.2500        S  NaN
# 1              1  female  38.0      1      0  71.2833        C    C
# 3              1  female  26.0      0      0   7.9250        S  NaN
# 1              1  female  35.0      1      0  53.1000        S    C
# 3              0    male  35.0      0      0   8.0500        S  NaN

# %%
pd.read_csv('titanic.csv',header=0).head()#header is selected row wise
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
pd.read_csv('titanic.csv',header=None).head()
# Out:
#           0       1       2     3      4      5        6         7     8
# 0  survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1         0       3    male  22.0      1      0     7.25         S   NaN
# 2         1       1  female  38.0      1      0  71.2833         C     C
# 3         1       3  female  26.0      0      0    7.925         S   NaN
# 4         1       1  female  35.0      1      0     53.1         S     C

# %%
pd.read_csv('titanic.csv',header=None,names=["Alive", "Class", "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"]).head()
# Out:
#       Alive   Class  Gender   Age  SipSp  ParCh     Fare       Emb  Deck
# 0  survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1         0       3    male  22.0      1      0     7.25         S   NaN
# 2         1       1  female  38.0      1      0  71.2833         C     C
# 3         1       3  female  26.0      0      0    7.925         S   NaN
# 4         1       1  female  35.0      1      0     53.1         S     C

# %%
pd.read_csv('titanic.csv',usecols=['pclass','survived','age','fare']).head()
# Out:
#    survived  pclass   age     fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
t=pd.read_csv('titanic.csv',index_col='pclass')

# %%
t.columns=["Alive",  "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"]

# %%
t.head()
# Out:
#         Alive  Gender   Age  SipSp  ParCh     Fare Emb Deck
# pclass
# 3           0    male  22.0      1      0   7.2500   S  NaN
# 1           1  female  38.0      1      0  71.2833   C    C
# 3           1  female  26.0      0      0   7.9250   S  NaN
# 1           1  female  35.0      1      0  53.1000   S    C
# 3           0    male  35.0      0      0   8.0500   S  NaN

# %%
t.index.name='class'

# %%
t.head()
# Out:
#        Alive  Gender   Age  SipSp  ParCh     Fare Emb Deck
# class
# 3          0    male  22.0      1      0   7.2500   S  NaN
# 1          1  female  38.0      1      0  71.2833   C    C
# 3          1  female  26.0      0      0   7.9250   S  NaN
# 1          1  female  35.0      1      0  53.1000   S    C
# 3          0    male  35.0      0      0   8.0500   S  NaN

# %%
#Importing and rectifying messy data

# %%
pd.read_csv('titanic_raw.csv').head()
# Out:
#                                             This       is       the   Titanic  \
# It   contains  all       passengers  that   were   aboard       the   titanic
# the  tragic    disaster  occured     in      the     year        19         1
# 0   0         3         male        22.0       1        0     $7.25         S
# 1   1         1         female      38.0       1        0  $71.2833         C
# 2   1         3         female      26.0       0        0    $7.925         S
#
#                                            Dataset.
# It   contains  all       passengers  that      when
# the  tragic    disaster  occured     in           2
# 0   0         3         male        22.0        NaN
# 1   1         1         female      38.0          C
# 2   1         3         female      26.0        NaN

# %%
pd.read_csv('titanic_raw.csv').tail()#messy data with unncessary cols and rows
# Out:
#                                      This    is      the  Titanic  Dataset.
# 891 0     2         male     24.0       0     0    $10.5        S       NaN
# 892 0     3         male     34.0       1     1    $14.4        S       NaN
# 893 0     3         male     36.0       0     0  $7.8958        S       NaN
# End  of    the       Dataset                         NaN      NaN       NaN
# Get  more  Datasets  on       Kaggle    .   com      NaN      NaN       NaN

# %%
t=pd.read_csv('titanic_raw.csv',skiprows=2,skipfooter=2)
# Out:
# C:\Users\Haider\Desktop\New folder\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
t.columns=['x',"Survived", "Class", "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"]

# %%
t.drop(columns='x',inplace=True)

# %%
t.to_csv('titanic_imp01.csv')#Exporting as csv file

# %%
pd.read_csv('titanic_imp01.csv').head()#importing are new saved file
#an extra index appears file importing, default function
# Out:
#    Unnamed: 0 Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0           0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1           1        1      1  female  38.0      1      0  $71.2833   C    C
# 2           2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3           3        1      1  female  35.0      1      0     $53.1   S    C
# 4           4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
#Importing from excel files

# %%
pd.read_excel('sales.xls',index_col=0,header=0)
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
pd.read_excel('sales.xls',index_col=0,header=0,usecols="A:C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel('sales.xls',index_col=0,header=0,usecols="A,C:D")
# Out:
#        Country  Sales
# Mike       USA     25
# Jim        USA     43
# Steven      UK     76
# Joe      Spain     12
# Tom     France     89

# %%
pd.read_excel('sales.xls',index_col=0,header=0,usecols=['City','Sales'])
#Working in newer version
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_excel('sales.xls',index_col=0,header=0,usecols=[1,3,4])
#Note slicing doesn't work with numbers
# Out:
#           Sales  Bonus
# City
# New York     25   2.50
# Boston       43   4.30
# London       76   7.60
# Madrid       12   1.80
# Paris        89  13.35

# %%
pd.read_excel('sales.xls',index_col=0,header=0,usecols=":C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel('sales.xls',index_col=0,header=0,usecols="C:")
#doesn't work the opposite way, the end needs to be specified
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_excel("sales.xls", header = 0, names = [ "Loc_City", "Loc_Country", "Revenue", "Add_Comp"])
# Out:
#         Loc_City Loc_Country  Revenue  Add_Comp
# Mike    New York         USA       25      2.50
# Jim       Boston         USA       43      4.30
# Steven    London          UK       76      7.60
# Joe       Madrid       Spain       12      1.80
# Tom        Paris      France       89     13.35

# %%
pd.read_excel('Lux Industries.xlsx', sheet_name='Sheet3')
#using sheet to track right sheetin excel
# Out:
#                     Unnamed: 0  2010-03-31 00:00:00  2011-03-31 00:00:00  \
# 0                        Sales               333.94               520.54
# 1                     Expenses               324.18               498.25
# 2                    OP Profit                 9.76                22.29
# 3                          OPM            0.0292268            0.0428209
# 4                 Other Income                 2.81                  0.1
# 5                     Interest                  4.7                 6.92
# 6                 Depreciation                 1.14                 2.96
# 7                          PBT                 6.73                12.51
# 8                          Tax                 2.31                 4.14
# 9                   Net Profit                 4.42                 8.37
# 10                         NPM            0.0132359            0.0160795
# 11           Dividend Payout %             0.239819             0.139785
# ...

# %%
pd.read_excel('Lux Industries.xlsx', sheet_name='Sheet3',skipfooter=4,)
# Out:
#                     Unnamed: 0  2010-03-31 00:00:00  2011-03-31 00:00:00  \
# 0                        Sales               333.94               520.54
# 1                     Expenses               324.18               498.25
# 2                    OP Profit                 9.76                22.29
# 3                          OPM            0.0292268            0.0428209
# 4                 Other Income                 2.81                  0.1
# 5                     Interest                  4.7                 6.92
# 6                 Depreciation                 1.14                 2.96
# 7                          PBT                 6.73                12.51
# 8                          Tax                 2.31                 4.14
# 9                   Net Profit                 4.42                 8.37
# 10                         NPM            0.0132359            0.0160795
# 11           Dividend Payout %             0.239819             0.139785
# ...

# %%
pd.read_excel('Lux Industries.xlsx', sheet_name='Sheet3',usecols='A:K').head()
# Out:
#      Unnamed: 0 2010-03-31 00:00:00 2011-03-31 00:00:00 2012-03-31 00:00:00  \
# 0         Sales              333.94              520.54              547.49
# 1      Expenses              324.18              498.25              514.81
# 2     OP Profit                9.76               22.29               32.68
# 3           OPM           0.0292268           0.0428209           0.0596906
# 4  Other Income                2.81                 0.1                0.05
#
#   2013-03-31 00:00:00 2014-03-31 00:00:00 2015-03-31 00:00:00  \
# 0              691.81              870.63              908.96
# 1              647.05               801.1              827.69
# 2               44.76               69.53               81.27
# 3           0.0646998           0.0798617           0.0894099
# 4                0.08                0.51                0.15
#
#   2016-03-31 00:00:00 2017-03-31 00:00:00 2018-03-31 00:00:00  \
# 0              940.87              957.97             1077.51
# ...

# %%
#Performing operationss above on a real messy dataset, and ustilising read_excel
#options

# %%
#Importing from web

# %%
url = "https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table"

# %%
pd.read_html(url)
#the following is multiple table is the form of a list
#Further lets view individual tables
# Out:
# [                    0                          1     2       3       4      5
#  0                Rank                        NOC  Gold  Silver  Bronze  Total
#  1                   1         Soviet Union (URS)    49      41      35    125
#  2                   2         East Germany (GDR)    40      25      25     90
#  3                   3        United States (USA)    34      35      25     94
#  4                   4         West Germany (FRG)    10      12      17     39
#  5                   5                Japan (JPN)     9       6      10     25
#  6                   6               Poland (POL)     7       6      13     26
#  7                   7             Bulgaria (BUL)     6       9       7     22
#  8                   8                 Cuba (CUB)     6       4       3     13
#  9                   9              Romania (ROU)     4       9      14     27
#  10                 10              Hungary (HUN)     4       5      13     22
# ...

# %%
pd.read_html(url,header=0)[0]
# Out:
#                  Rank                        NOC  Gold  Silver  Bronze  Total
# 0                   1         Soviet Union (URS)    49      41      35  125.0
# 1                   2         East Germany (GDR)    40      25      25   90.0
# 2                   3        United States (USA)    34      35      25   94.0
# 3                   4         West Germany (FRG)    10      12      17   39.0
# 4                   5                Japan (JPN)     9       6      10   25.0
# 5                   6               Poland (POL)     7       6      13   26.0
# 6                   7             Bulgaria (BUL)     6       9       7   22.0
# 7                   8                 Cuba (CUB)     6       4       3   13.0
# 8                   9              Romania (ROU)     4       9      14   27.0
# 9                  10              Hungary (HUN)     4       5      13   22.0
# 10                 11              Finland (FIN)     4       2       0    6.0
# ...

# %%
pd.read_html(url,header=0)[1]#a table we don't require
# Out:
#                        vteOlympic Games medal tables  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                                           Unnamed: 1
# 0                                                NaN
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3                                                NaN

# %%
medals_1976=pd.read_html(url,header=0)[0]

# %%
medals_1976.to_excel('medals_1976.xls')
#saving as excel file
