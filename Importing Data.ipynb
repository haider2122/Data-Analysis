# %%
import pandas as pd

# %% [raw]
# CSV stands for comma separated values.
# all data is of text format

# %%
with open('titanic.csv') as f:
    st=f.readlines()

# %%
st# hence the following is of a csv text format
# Out:
# ['survived,pclass,sex,age,sibsp,parch,fare,embarked,deck\n',
#  '0,3,male,22.0,1,0,7.25,S,\n',
#  '1,1,female,38.0,1,0,71.2833,C,C\n',
#  '1,3,female,26.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,53.1,S,C\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.4583,Q,\n',
#  '0,1,male,54.0,0,0,51.8625,S,E\n',
#  '0,3,male,2.0,3,1,21.075,S,\n',
#  '1,3,female,27.0,0,2,11.1333,S,\n',
#  '1,2,female,14.0,1,0,30.0708,C,\n',
#  '1,3,female,4.0,1,1,16.7,S,G\n',
#  '1,1,female,58.0,0,0,26.55,S,C\n',
#  '0,3,male,20.0,0,0,8.05,S,\n',
#  '0,3,male,39.0,1,5,31.275,S,\n',
#  '0,3,female,14.0,0,0,7.8542,S,\n',
#  '1,2,female,55.0,0,0,16.0,S,\n',
#  '0,3,male,2.0,4,1,29.125,Q,\n',
#  '1,2,male,,0,0,13.0,S,\n',
#  '0,3,female,31.0,1,0,18.0,S,\n',
#  '1,3,female,,0,0,7.225,C,\n',
#  '0,2,male,35.0,0,0,26.0,S,\n',
#  '1,2,male,34.0,0,0,13.0,S,D\n',
#  '1,3,female,15.0,0,0,8.0292,Q,\n',
#  '1,1,male,28.0,0,0,35.5,S,A\n',
#  '0,3,female,8.0,3,1,21.075,S,\n',
#  '1,3,female,38.0,1,5,31.3875,S,\n',
# ...

# %%
t=pd.read_csv('titanic.csv',index_col='sex').head(2)#setting sex as index col

# %%
pd.read_csv('titanic.csv',header=None).head(2)#we in this case have set header as none
#we can set header as any row(default=0)
# Out:
#           0       1     2     3      4      5     6         7     8
# 0  survived  pclass   sex   age  sibsp  parch  fare  embarked  deck
# 1         0       3  male  22.0      1      0  7.25         S   NaN

# %%
#Changing name of classes
pd.read_csv('titanic.csv',names=['alive','class','gender','parch','price','emb','dec']).head(2)
# Out:
#                 alive class gender  parch price       emb   dec
# survived pclass   sex   age  sibsp  parch  fare  embarked  deck
# 0        3       male  22.0      1      0  7.25         S   NaN

# %%
pd.read_csv('titanic.csv',usecols=['sex','age']).head(2)#Using specificcolumns
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0

# %% [raw]
# importing and exporting messsy CSV files

# %%
pd.read_csv('titanic_raw.csv')#The following is a messy file with unimportant data
# Out:
#      Unnamed: 0 Alive  Class  Gender           Age  Siblings  Parch     Price  \
# 0             0     0      3    male          22.0         1      0     $7.25
# 1             1     1      1  female          38.0         1      0  $71.2833
# 2             2     1      3  female          26.0         0      0    $7.925
# 3             3     1      1  female          35.0         1      0     $53.1
# 4             4     0      3    male          35.0         0      0     $8.05
# 5             5     0      3    male  Missing Data         0      0   $8.4583
# 6             6     0      1    male          54.0         0      0  $51.8625
# 7             7     0      3    male           2.0         3      1   $21.075
# 8             8     1      3  female          27.0         0      2  $11.1333
# 9             9     1      2  female          14.0         1      0  $30.0708
# 10           10     1      3  female           4.0         1      1     $16.7
# ...

# %%
#cleaning the following

# %%
col_names=['Alive','Class','Gender','Age','Siblings','Parch','Price','Emb','Deck']
#saving our new list of column labels

# %%
t=pd.read_csv('titanic_raw.csv',skiprows=3,skipfooter=2,header=None,names=col_names)
t# Cleaned and Customized data set
# Out:
# C:\Users\Haider\Desktop\New folder\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
#     Alive  Class  Gender           Age  Siblings  Parch      Price Emb Deck
# 2       1      3  female          26.0         0      0     $7.925   S  NaN
# 3       1      1  female          35.0         1      0      $53.1   S    C
# 4       0      3    male          35.0         0      0      $8.05   S  NaN
# 5       0      3    male  Missing Data         0      0    $8.4583   Q  NaN
# 6       0      1    male          54.0         0      0   $51.8625   S    E
# 7       0      3    male           2.0         3      1    $21.075   S  NaN
# 8       1      3  female          27.0         0      2   $11.1333   S  NaN
# 9       1      2  female          14.0         1      0   $30.0708   C  NaN
# ...

# %%
#Saving the new Cleaned file
t.to_csv('titanic_cleaned.csv')

# %%
f=pd.read_excel('sales.xls')

# %%
f
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %% [raw]
# #Reading Data From The web

# %%
url="https://www.screener.in/company/530233/#profit-loss"

# %%
print(type(pd.read_html(url)))
print(len(pd.read_html(url)))#we have imported Following data from screener
#Because several tables exist a list of table is present
#WE can obtain DF by list index
# Out:
# <class 'list'>
# 9

# %%
pd.read_html(url)[1]# The following is 1 table of out 9
#we can customize and export this table accordingly
# Out:
#            Unnamed: 0 Mar 2008 Mar 2009 Mar 2010 Mar 2011 Mar 2012 Mar 2013  \
# 0               Sales     5.70     9.78    12.08    20.83    25.44    44.28
# 1            Expenses     5.25     9.43    11.32    19.09    23.33    41.01
# 2    Operating Profit     0.45     0.35     0.76     1.74     2.11     3.27
# 3               OPM %    7.89%    3.58%    6.29%    8.35%    8.29%    7.38%
# 4        Other Income     0.02     0.38     0.08     0.03     0.05     0.06
# 5            Interest     0.18     0.38     0.42     1.12     1.43     1.85
# 6        Depreciation     0.25     0.26     0.34     0.44     0.47     0.72
# 7   Profit before tax     0.04     0.09     0.08     0.21     0.26     0.76
# 8               Tax %    0.00%   11.11%    0.00%    0.00%    0.00%    0.00%
# 9          Net Profit     0.04     0.08     0.08     0.21     0.26     0.77
# 10          EPS in Rs     0.06     0.13     0.13     0.34     0.42     1.23
# ...
