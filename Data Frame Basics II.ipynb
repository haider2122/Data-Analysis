# %%
import pandas as pd

# %%
t=pd.read_csv('titanic.csv')

# %%
q=(t.loc[::,['sex']]=='male')#Getting true or false for out male values
q
# Out:
#        sex
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8    False
# 9    False
# 10   False
# 11   False
# 12    True
# 13    True
# 14   False
# 15   False
# 16    True
# 17    True
# 18   False
# 19   False
# 20    True
# 21    True
# 22   False
# 23    True
# 24   False
# 25   False
# 26    True
# 27    True
# 28   False
# 29    True
# ..     ...
# 861   True
# 862  False
# 863  False
# 864   True
# 865  False
# 866  False
# 867   True
# 868   True
# 869   True
# 870   True
# 871  False
# 872   True
# 873   True
# 874  False
# 875  False
# 876   True
# 877   True
# 878   True
# 879  False
# 880  False
# 881   True
# 882  False
# 883   True
# 884   True
# 885  False
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
p=t[t.loc[::,'sex']=='male']#True false values within t[] gives us respective male values
p
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked deck
# 0           0       3  male  22.0      1      0    7.2500        S  NaN
# 4           0       3  male  35.0      0      0    8.0500        S  NaN
# 5           0       3  male   NaN      0      0    8.4583        Q  NaN
# 6           0       1  male  54.0      0      0   51.8625        S    E
# 7           0       3  male   2.0      3      1   21.0750        S  NaN
# 12          0       3  male  20.0      0      0    8.0500        S  NaN
# 13          0       3  male  39.0      1      5   31.2750        S  NaN
# 16          0       3  male   2.0      4      1   29.1250        Q  NaN
# 17          1       2  male   NaN      0      0   13.0000        S  NaN
# 20          0       2  male  35.0      0      0   26.0000        S  NaN
# 21          1       2  male  34.0      0      0   13.0000        S    D
# 23          1       1  male  28.0      0      0   35.5000        S    A
# ...

# %%
p=t[t.loc[::,'sex']=='male'].loc[::,'fare']#finding fare nsew data frame with only mail value
p
# Out:
# 0        7.2500
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 12       8.0500
# 13      31.2750
# 16      29.1250
# 17      13.0000
# 20      26.0000
# 21      13.0000
# 23      35.5000
# 26       7.2250
# 27     263.0000
# 29       7.8958
# 30      27.7208
# 33      10.5000
# 34      82.1708
# 35      52.0000
# 36       7.2292
# 37       8.0500
# 42       7.8958
# 45       8.0500
# 46      15.5000
# 48      21.6792
# 50      39.6875
# 51       7.8000
# 54      61.9792
# 55      35.5000
# 57       7.2292
#          ...
# 840      7.9250
# 841     10.5000
# 843      6.4375
# 844      8.6625
# 845      7.5500
# 846     69.5500
# 847      7.8958
# 848     33.0000
# 850     31.2750
# 851      7.7750
# 857     26.5500
# 859      7.2292
# 860     14.1083
# 861     11.5000
# 864     13.0000
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 872      5.0000
# 873      9.0000
# 876      9.8458
# 877      7.8958
# 878      7.8958
# ...

# %%
f=(t.dtypes==float)

# %%
#Find statistics of male passengers survial and fare

# %%
x=t[t.loc[::,'sex']=='male']

# %%
x
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked deck
# 0           0       3  male  22.0      1      0    7.2500        S  NaN
# 4           0       3  male  35.0      0      0    8.0500        S  NaN
# 5           0       3  male   NaN      0      0    8.4583        Q  NaN
# 6           0       1  male  54.0      0      0   51.8625        S    E
# 7           0       3  male   2.0      3      1   21.0750        S  NaN
# 12          0       3  male  20.0      0      0    8.0500        S  NaN
# 13          0       3  male  39.0      1      5   31.2750        S  NaN
# 16          0       3  male   2.0      4      1   29.1250        Q  NaN
# 17          1       2  male   NaN      0      0   13.0000        S  NaN
# 20          0       2  male  35.0      0      0   26.0000        S  NaN
# 21          1       2  male  34.0      0      0   13.0000        S    D
# 23          1       1  male  28.0      0      0   35.5000        S    A
# ...

# %%
gender=x.sex
age_male=[x.loc[::,'age']>18]

# %%
r=(age_male and gender)#View lecture 53 for more

# %%
r
# Out:
# 0      male
# 4      male
# 5      male
# 6      male
# 7      male
# 12     male
# 13     male
# 16     male
# 17     male
# 20     male
# 21     male
# 23     male
# 26     male
# 27     male
# 29     male
# 30     male
# 33     male
# 34     male
# 35     male
# 36     male
# 37     male
# 42     male
# 45     male
# 46     male
# 48     male
# 50     male
# 51     male
# 54     male
# 55     male
# 57     male
#        ...
# 840    male
# 841    male
# 843    male
# 844    male
# 845    male
# 846    male
# 847    male
# 848    male
# 850    male
# 851    male
# 857    male
# 859    male
# 860    male
# 861    male
# 864    male
# 867    male
# 868    male
# 869    male
# 870    male
# 872    male
# 873    male
# 876    male
# 877    male
# 878    male
# 881    male
# 883    male
# 884    male
# 886    male
# 889    male
# 890    male
# Name: sex, Length: 577, dtype: object

# %%
t
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 5           0       3    male   NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 7           0       3    male   2.0      3      1   21.0750        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 9           1       2  female  14.0      1      0   30.0708        C  NaN
# 10          1       3  female   4.0      1      1   16.7000        S    G
# 11          1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
fe=t.sex=="female"
ch=t.age<14
fe_or_ch=t.loc[(fe | ch)]

# %%
fe_or_ch.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN

# %%
fe_or_ch.describe()#Survival rate for female and children is 72%
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  351.000000  351.000000  298.000000  351.000000  351.000000  351.000000
# mean     0.723647    2.205128   25.039161    0.846154    0.723647   43.441786
# std      0.447832    0.847232   15.314631    1.306787    1.008809   55.676194
# min      0.000000    1.000000    0.420000    0.000000    0.000000    6.750000
# 25%      0.000000    1.000000   14.125000    0.000000    0.000000   12.475000
# 50%      1.000000    2.000000   24.000000    0.000000    0.000000   24.150000
# 75%      1.000000    3.000000   35.000000    1.000000    1.000000   51.931250
# max      1.000000    3.000000   63.000000    8.000000    6.000000  512.329200

# %%
olym=pd.read_csv('summer.csv')

# %%
yr_90=(olym.loc[::,'Year']==1900)#Using iloc to stisfy conditions

# %%
olym.loc[yr_90]
# Out:
#      Year   City       Sport  Discipline                            Athlete  \
# 151  1900  Paris    Aquatics    Swimming                     HALMAY, Zoltan
# 152  1900  Paris    Aquatics    Swimming                JARVIS, John Arthur
# 153  1900  Paris    Aquatics    Swimming                        WAHLE, Otto
# 154  1900  Paris    Aquatics    Swimming                    DROST, Johannes
# 155  1900  Paris    Aquatics    Swimming                  HOPPENBERG, Ernst
# 156  1900  Paris    Aquatics    Swimming                       RUBERL, Karl
# 157  1900  Paris    Aquatics    Swimming                       RUBERL, Karl
# 158  1900  Paris    Aquatics    Swimming               LANE, Frederick C.V.
# 159  1900  Paris    Aquatics    Swimming                     HALMAY, Zoltan
# 160  1900  Paris    Aquatics    Swimming                        KEMP, Peter
# 161  1900  Paris    Aquatics    Swimming               LANE, Frederick C.V.
# ...

# %%
x=olym.loc[olym.Year.isin([1996,2012])]#Considering game with isin 
x.head(2)
# Out:
#        Year     City     Sport Discipline         Athlete Country Gender  \
# 21302  1996  Atlanta  Aquatics     Diving  XIAO, Hailiang     CHN    Men
# 21303  1996  Atlanta  Aquatics     Diving  SAUTIN, Dmitry     RUS    Men
#
#               Event   Medal
# 21302  10M Platform  Bronze
# 21303  10M Platform    Gold

# %%
x.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %% [raw]
# Using All and Any method

# %%
(t.loc[::,'age']==42).any()#check if even one condition is satisfied
# Out:
# True

# %%
(t.fare<1000).all()#All fare valuesare lesser than 1000
# Out:
# True

# %%
olym1=olym.drop(columns=['Sport','Event'])#Dropping Columns is a list form using
olym.head(2)                             #drop method
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver

# %%
olym2=olym.drop(labels='City',axis='columns')
olym2.head(2)#using label method to drop column, which requires defining axis
# Out:
#    Year     Sport Discipline           Athlete Country Gender           Event  \
# 0  1896  Aquatics   Swimming     HAJOS, Alfred     HUN    Men  100M Freestyle
# 1  1896  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men  100M Freestyle
#
#     Medal
# 0    Gold
# 1  Silver

# %% [raw]
# #dropping rows
# olym.drop(labels='HAJOS, Alfred',axis=0)#Verifyy why not working,lec-58

# %%
c1=(olym.loc[::,'Year']==1996)
c2=(olym.Sport.isin(['Aquatics']))
olym_d=olym.loc[~(c1 | c2)]#To take values which are not in C1 or C2

# %%
print((olym_d.Sport=="Aquatics").any())
print((olym_d.Year==1996).any())
# Hence we removed value of or diciple  aquaticc and year 1996
# Out:
# False
# False

# %%
#Adding new columns

# %%
t.loc[::,'New Column']='Nothing'#We can not do the same with attribute method

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#   New Column
# 0    Nothing
# 1    Nothing
# 2    Nothing
# 3    Nothing
# 4    Nothing

# %%
t.drop(columns='New Column',inplace=True)

# %%
#Finding year of birth
t.loc[::,'YOB']=1912-t.age
t.loc[::,'Adult']=t.age>18
t
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 5           0       3    male   NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 7           0       3    male   2.0      3      1   21.0750        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 9           1       2  female  14.0      1      0   30.0708        C  NaN
# 10          1       3  female   4.0      1      1   16.7000        S    G
# 11          1       1  female  58.0      0      0   26.5500        S    C
# ...

# %% [raw]
# Using Insert method to Add columns

# %%
x=[]
for i in range(0,t.Adult.size):
    if t.Adult[i]==True:
        if t.sex[i]=='male':
            x.append('Man')
        elif t.sex[i]=='female':
            x.append('woman')
    else:
        x.append('Na')
        
#Creating Another column

# %%
t.insert(loc=9,column='Classification',value=x)
t.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
#
#   Classification     YOB  Adult
# 0            Man  1890.0   True
# 1          woman  1874.0   True

# %% [raw]
# Creating a Data Frame

# %%
#First methdo
player=['Messi','Ronaldo','Neymar']
Country=['Argentina','Portugal','Brazil']
Goals=[45,44,40]
d={'Name':player,'Nationality':Country,'No Goals':Goals}
df=pd.DataFrame(data=d)
df
# Out:
#       Name Nationality  No Goals
# 0    Messi   Argentina        45
# 1  Ronaldo    Portugal        44
# 2   Neymar      Brazil        40

# %%
#second Method
s=pd.Series(data=Country,index=player,name='Nationality')
s.to_frame()
s#we converted Series to a data frame, and can add columns from here on
# Out:
# Messi      Argentina
# Ronaldo     Portugal
# Neymar        Brazil
# Name: Nationality, dtype: object

# %% [raw]
# Adding New Rows

# %%
df.loc[3,::]=['Ramos','Spain',20]
df.tail(1)#Hence new row added
# Out:
#     Name Nationality  No Goals
# 3  Ramos       Spain      20.0
