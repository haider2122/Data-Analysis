# %%
#Conditional Manipulations to Dataframes

# %%
import pandas as pd
t=pd.read_csv('titanic.csv')

# %%
t.sex=='male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27      True
# 28     False
# 29      True
#        ...
# 861     True
# 862    False
# 863    False
# 864     True
# 865    False
# 866    False
# 867     True
# 868     True
# 869     True
# 870     True
# 871    False
# 872     True
# 873     True
# 874    False
# 875    False
# 876     True
# 877     True
# 878     True
# 879    False
# 880    False
# 881     True
# 882    False
# 883     True
# 884     True
# 885    False
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
t.loc[t.sex=='male'].head()
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0         0       3  male  22.0      1      0   7.2500        S  NaN
# 4         0       3  male  35.0      0      0   8.0500        S  NaN
# 5         0       3  male   NaN      0      0   8.4583        Q  NaN
# 6         0       1  male  54.0      0      0  51.8625        S    E
# 7         0       3  male   2.0      3      1  21.0750        S  NaN

# %%
#Finding fare for all male passengers

# %%
t.loc[t.sex=='male','fare']
# Out:
# 0        7.2500
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 12       8.0500
# 13      31.2750
# 16      29.1250
# 17      13.0000
# 20      26.0000
# 21      13.0000
# 23      35.5000
# 26       7.2250
# 27     263.0000
# 29       7.8958
# 30      27.7208
# 33      10.5000
# 34      82.1708
# 35      52.0000
# 36       7.2292
# 37       8.0500
# 42       7.8958
# 45       8.0500
# 46      15.5000
# 48      21.6792
# 50      39.6875
# 51       7.8000
# 54      61.9792
# 55      35.5000
# 57       7.2292
#          ...
# 840      7.9250
# 841     10.5000
# 843      6.4375
# 844      8.6625
# 845      7.5500
# 846     69.5500
# 847      7.8958
# 848     33.0000
# 850     31.2750
# 851      7.7750
# 857     26.5500
# 859      7.2292
# 860     14.1083
# 861     11.5000
# 864     13.0000
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 872      5.0000
# 873      9.0000
# 876      9.8458
# 877      7.8958
# 878      7.8958
# ...

# %%
t.loc[t.age>30]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 11          1       1  female  58.0      0      0   26.5500        S    C
# 13          0       3    male  39.0      1      5   31.2750        S  NaN
# 15          1       2  female  55.0      0      0   16.0000        S  NaN
# 18          0       3  female  31.0      1      0   18.0000        S  NaN
# 20          0       2    male  35.0      0      0   26.0000        S  NaN
# 21          1       2    male  34.0      0      0   13.0000        S    D
# 25          1       3  female  38.0      1      5   31.3875        S  NaN
# 30          0       1    male  40.0      0      0   27.7208        C  NaN
# ...

# %%
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
t.loc[t.pclass==3].survived.mean()#Filtering and finding average foro pclass 3
# Out:
# 0.24236252545824846

# %%
t.loc[t.pclass==1,'survived'].mean()#FIltering and finding average using only forpclass1
# Out:
# 0.6296296296296297

# %%
t.dtypes=='int64'
# Out:
# survived     True
# pclass       True
# sex         False
# age         False
# sibsp        True
# parch        True
# fare        False
# embarked    False
# deck        False
# dtype: bool

# %%
#Using two conditions in combination

# %%
c1=t.sex=='male'
c2=t.age>19

# %%
t.loc[(c1 & c2)].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0          0       3  male  22.0      1      0   7.2500        S  NaN
# 4          0       3  male  35.0      0      0   8.0500        S  NaN
# 6          0       1  male  54.0      0      0  51.8625        S    E
# 12         0       3  male  20.0      0      0   8.0500        S  NaN
# 13         0       3  male  39.0      1      5  31.2750        S  NaN

# %%
t.loc[(c1 & c2)].survived.mean()
# Out:
# 0.18406593406593408

# %%
t.describe()#Adult male passenger survival rate was 18% compared to avg 38%
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#using OR conditions

# %%
c1=t.sex=='female'
c2=t.age<18
c3=t.pclass==1

# %%
t_w_ch_pcl1=t.loc[((c1 | c2) & c2)]

# %%
t_w_ch_pcl1.describe()#53% survival rate
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  113.000000  113.000000  113.000000  113.000000  113.000000  113.000000
# mean     0.539823    2.584071    9.041327    1.460177    1.053097   31.220798
# std      0.500632    0.677781    6.030408    1.625881    0.800008   32.538092
# min      0.000000    1.000000    0.420000    0.000000    0.000000    7.054200
# 25%      0.000000    2.000000    3.000000    0.000000    0.000000   12.287500
# 50%      1.000000    3.000000    9.000000    1.000000    1.000000   23.000000
# 75%      1.000000    3.000000   16.000000    3.000000    2.000000   34.375000
# max      1.000000    3.000000   17.000000    5.000000    3.000000  211.337500

# %%
t.loc[(c1 | c2)].survived.mean()
# Out:
# 0.6881720430107527

# %%
#Using between is in

# %%
#=>>complete later, lec-56

# %%
#using any()and all()

# %%
(t.age==26).any()
# Out:
# True

# %%
(t.survived==(1 | 0)).all()
# Out:
# False

# %%
l=[0,0,1,2]
pd.Series(l).any()#Checls for 0 on defualt basis
# Out:
# True

# %%
pd.Series(l).all()#pd.Series(l).all()#
# Out:
# False

# %%
#Deleting Columns

# %%
s=pd.read_csv("summer.csv")
s.head(2)
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver

# %%
s.drop(columns=['Sport'],inplace=False).head()
#while using columns directly we donot need to use axis
# Out:
#    Year    City Discipline             Athlete Country Gender  \
# 0  1896  Athens   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
s.drop(labels=['Sport'],axis=1,inplace=False).head()
# Out:
#    Year    City Discipline             Athlete Country Gender  \
# 0  1896  Athens   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
s.loc[:,['Year','City','Athlete']].head()
# Out:
#    Year    City             Athlete
# 0  1896  Athens       HAJOS, Alfred
# 1  1896  Athens    HERSCHMANN, Otto
# 2  1896  Athens   DRIVAS, Dimitrios
# 3  1896  Athens  MALOKINIS, Ioannis
# 4  1896  Athens  CHASAPIS, Spiridon

# %%
#The above is method of selevcting columns. W.r.t scenarios delete to select.

# %%
#Dropping Rows

# %%
s.drop(index=0,inplace=False).head()#We dropped index 0 of integer
# Out:
#    Year    City     Sport Discipline                Athlete Country Gender  \
# 1  1896  Athens  Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
#
#                         Event   Medal
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver
# 5             1200M Freestyle  Bronze

# %%
s.set_index('Athlete',inplace=True)

# %%
s.drop(index=['HAJOS, Alfred','HERSCHMANN, Otto'],inplace=False).head()
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                             Event   Medal
# Athlete
# DRIVAS, Dimitrios      100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios             1200M Freestyle  Bronze
# ANDREOU, Joannis                  1200M Freestyle  Silver

# %%
s.drop(labels=['HAJOS, Alfred','HERSCHMANN, Otto'],axis=0,inplace=False).head()
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                             Event   Medal
# Athlete
# DRIVAS, Dimitrios      100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios             1200M Freestyle  Bronze
# ANDREOU, Joannis                  1200M Freestyle  Silver

# %%
#creating new columns
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
t.drop(columns=['zero','zeroes','XYZ','age-gender-pclass','age-pclass-gender'],inplace=True)
c1=t.age<18
c2=t.sex=='female'
c3=t.pclass==1
l=((c1|c2)&c3)
t['age-pclass-gender']=l
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    age-pclass-gender
# 0              False
# 1               True
# 2              False
# 3               True
# 4              False

# %%
t['Relatives']=(t.sibsp+t.parch)

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0       0.0     3.0    male  22.0    1.0    0.0   7.2500        S  NaN
# 1       1.0     1.0  female  38.0    1.0    0.0  71.2833        C    C
# 2       1.0     3.0  female  26.0    0.0    0.0   7.9250        S  NaN
# 3       1.0     1.0  female  35.0    1.0    0.0  53.1000        S    C
# 4       0.0     3.0    male  35.0    0.0    0.0   8.0500        S  NaN
#
#    age-pclass-gender  Relatives
# 0                0.0        1.0
# 1                1.0        1.0
# 2                0.0        0.0
# 3                1.0        1.0
# 4                0.0        0.0

# %%
#Using Insert Method

# %%
t.insert(loc=6,column='YOB',value=(1912-t.age))

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     YOB     fare embarked  \
# 0       0.0     3.0    male  22.0    1.0    0.0  1890.0   7.2500        S
# 1       1.0     1.0  female  38.0    1.0    0.0  1874.0  71.2833        C
# 2       1.0     3.0  female  26.0    0.0    0.0  1886.0   7.9250        S
# 3       1.0     1.0  female  35.0    1.0    0.0  1877.0  53.1000        S
# 4       0.0     3.0    male  35.0    0.0    0.0  1877.0   8.0500        S
#
#   deck  age-pclass-gender  Relatives
# 0  NaN                0.0        1.0
# 1    C                1.0        1.0
# 2  NaN                0.0        0.0
# 3    C                1.0        1.0
# 4  NaN                0.0        0.0

# %%
#Creating Data datafrme

# %%
#pd.DataFrame(#use dic, lists, tuples etc)
#or use hands-on approach below

# %%
Ath=pd.Series(s.Sport).to_frame()

# %%
Ath.insert(loc=1,column='Medal',value=(s.Medal))

# %%
Ath#keep adding rows and columns further to tamper with data set
# Out:
#                                        Sport   Medal
# Athlete
# HAJOS, Alfred                       Aquatics    Gold
# HERSCHMANN, Otto                    Aquatics  Silver
# DRIVAS, Dimitrios                   Aquatics  Bronze
# MALOKINIS, Ioannis                  Aquatics    Gold
# CHASAPIS, Spiridon                  Aquatics  Silver
# CHOROPHAS, Efstathios               Aquatics  Bronze
# HAJOS, Alfred                       Aquatics    Gold
# ANDREOU, Joannis                    Aquatics  Silver
# CHOROPHAS, Efstathios               Aquatics  Bronze
# NEUMANN, Paul                       Aquatics    Gold
# PEPANOS, Antonios                   Aquatics  Silver
# LANE, Francis                      Athletics  Bronze
# SZOKOLYI, Alajos                   Athletics  Bronze
# BURKE, Thomas                      Athletics    Gold
# HOFMANN, Fritz                     Athletics  Silver
# CURTIS, Thomas                     Athletics    Gold
# GOULDING, Grantley                 Athletics  Silver
# ...
