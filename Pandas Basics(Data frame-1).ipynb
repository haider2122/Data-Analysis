# %%
import pandas as pd

# %%
pd.options.display.max_rows=10
t=pd.read_csv("Titanic.csv")
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
t.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
t.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
print(t.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
t.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
t.shape
# Out:
# (891, 9)

# %%
t.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]>

# %%
print(type(t))
print(list(t))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'deck']

# %%
len(t)
# Out:
# 891

# %%
round(t,0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
print(min(t))
print(t.min())
print(t.size)
# Out:
# age
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare             0
# dtype: object
# 8019

# %%
t.sort_values(by='age',ascending=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print(t.age)
print('/n')
print(type(t.age))
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64
# /n
# <class 'pandas.core.series.Series'>

# %%
t['age']
t[['age','pclass']]
# Out:
#       age  pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
print(t.age.equals(t['age']))
#Both are series
print(t.age.equals(t[['age']]))
# Out:
# True
# False

# %%
t[0:4]
t[0:10:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 8         1       3  female  27.0      0      2  11.1333        S  NaN

# %%
olym=pd.read_csv('summer.csv')

# %%
olym
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
olym.iloc[4]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Athlete               CHASAPIS, Spiridon
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Silver
# Name: 4, dtype: object

# %%
olym.iloc[0:2]
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver

# %%
olym.iloc[[1,2,789]]
# Out:
#      Year      City      Sport Discipline            Athlete Country Gender  \
# 1    1896    Athens   Aquatics   Swimming   HERSCHMANN, Otto     AUT    Men
# 2    1896    Athens   Aquatics   Swimming  DRIVAS, Dimitrios     GRE    Men
# 789  1904  St Louis  Athletics  Athletics      JONES, Samuel     USA    Men
#
#                           Event   Medal
# 1                100M Freestyle  Silver
# 2    100M Freestyle For Sailors  Bronze
# 789                   High Jump    Gold

# %%
olym.iloc[0:5,[1,2,3]]
# Out:
#      City     Sport Discipline
# 0  Athens  Aquatics   Swimming
# 1  Athens  Aquatics   Swimming
# 2  Athens  Aquatics   Swimming
# 3  Athens  Aquatics   Swimming
# 4  Athens  Aquatics   Swimming

# %%
olym.iloc[2:9,2:9:]
# Out:
#       Sport Discipline                Athlete Country Gender  \
# 2  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
#
#                         Event   Medal
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver
# 5             1200M Freestyle  Bronze
# 6             1200M Freestyle    Gold
# 7             1200M Freestyle  Silver
# 8              400M Freestyle  Bronze

# %%
olym2=pd.read_csv("summer.csv",index_col='Athlete')
olym2 #Athlete acts as the index of table
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
olym2.loc["PHELPS, Michael"].iloc[0:4]
# Out:
#                  Year    City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
#
#                                   Event   Medal
# Athlete
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle  Bronze
# PHELPS, Michael  200M Individual Medley    Gold

# %%
olym2.loc["PHELPS, Michael"].iloc[8:15]
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
#
#                                   Event Medal
# Athlete
# PHELPS, Michael          100M Butterfly  Gold
# PHELPS, Michael          200M Butterfly  Gold
# PHELPS, Michael          200M Freestyle  Gold
# PHELPS, Michael  200M Individual Medley  Gold
# PHELPS, Michael  400M Individual Medley  Gold
# PHELPS, Michael  4X100M Freestyle Relay  Gold
# PHELPS, Michael     4X100M Medley Relay  Gold

# %%
olym.loc[0:3,'Year':'Country']
# Out:
#    Year    City     Sport Discipline             Athlete Country
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE

# %%
olym2.loc[['PHELPS, Michael','LANE, Francis',],['Year','Medal','Sport']]
# Out:
#                  Year   Medal      Sport
# Athlete
# PHELPS, Michael  2004    Gold   Aquatics
# PHELPS, Michael  2004    Gold   Aquatics
# PHELPS, Michael  2004  Bronze   Aquatics
# PHELPS, Michael  2004    Gold   Aquatics
# PHELPS, Michael  2004    Gold   Aquatics
# ...               ...     ...        ...
# PHELPS, Michael  2012    Gold   Aquatics
# PHELPS, Michael  2012  Silver   Aquatics
# PHELPS, Michael  2012    Gold   Aquatics
# PHELPS, Michael  2012    Gold   Aquatics
# LANE, Francis    1896  Bronze  Athletics
#
# [23 rows x 3 columns]

# %%
olym2.loc[['PHELPS, Michael','LANE, Francis','RAO, Babu'],['Year','Medal','Sport','Ph.no:']]
# Out:
# C:\Users\Haider\Desktop\New folder\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                    Year   Medal      Sport  Ph.no:
# Athlete
# PHELPS, Michael  2004.0    Gold   Aquatics     NaN
# PHELPS, Michael  2004.0    Gold   Aquatics     NaN
# PHELPS, Michael  2004.0  Bronze   Aquatics     NaN
# PHELPS, Michael  2004.0    Gold   Aquatics     NaN
# PHELPS, Michael  2004.0    Gold   Aquatics     NaN
# ...                 ...     ...        ...     ...
# PHELPS, Michael  2012.0  Silver   Aquatics     NaN
# PHELPS, Michael  2012.0    Gold   Aquatics     NaN
# PHELPS, Michael  2012.0    Gold   Aquatics     NaN
# LANE, Francis    1896.0  Bronze  Athletics     NaN
# ...

# %%
t.size
# Out:
# 8019
