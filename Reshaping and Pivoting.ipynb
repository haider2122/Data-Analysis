# %%
import pandas as pd
t=pd.read_csv('titanic.csv')

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# fare        891 non-null float64
# embarked    889 non-null object
# deck        203 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 52.2+ KB

# %%
#Transposing data frames

# %%
t=t.transpose()#Another way is t.T
t
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age         22       38      26      35    35     NaN       54       2
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...      881      882   883   884     885   886  \
# survived        1        1  ...        0        0     0     0       0     0
# pclass          3        2  ...        3        3     2     3       3     2
# ...

# %%
t.info()#Hence this is the transposed data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, survived to deck
# Columns: 891 entries, 0 to 890
# dtypes: object(891)
# memory usage: 31.5+ KB

# %%
t=t.transpose()#we try to attain the same data frame before

# %%
t.info()# but unfortunately data types are all changed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null object
# pclass      891 non-null object
# sex         891 non-null object
# age         714 non-null object
# sibsp       891 non-null object
# parch       891 non-null object
# fare        891 non-null object
# embarked    889 non-null object
# deck        203 non-null object
# dtypes: object(9)
# memory usage: 31.4+ KB

# %%
t.groupby('sex').survived.mean()# since the survived column is of object types
#after transpose
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-8-84b59246ec4b> in <module>()
# ----> 1 t.groupby('sex').survived.mean()# since the survived column is of object types
#       2 #after transpose
#
# C:\Users\Haider\Desktop\New folder\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# C:\Users\Haider\Desktop\New folder\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1054
#    1055         if len(output) == 0:
# -> 1056             raise DataError('No numeric types to aggregate')
#    1057
# ...

# %%
t=pd.read_csv('titanic.csv')

# %%
x=t.groupby(['sex','pclass']).survived.mean()

# %%
x.unstack().T#Transpoing the following statistics

# %%
t.T.T.info()#not useful and destroys data types

# %%
ta1=pd.read_csv('table1.csv')
ta1.head()

# %%
#Pivoting the following data set

# %%
ta1.pivot(index='Country',columns='Medal',values='Count').fillna(0).head()
#hence pivoting based on column index and values and then filling missing values

# %%
ta1.set_index(['Country','Medal']).unstack(-1,0)# The followig does the same as pivot

# %%
tb2=pd.read_csv('table2.csv')
tb2.head()#the following is thesame format with years

# %%
tb2.pivot(index='Country',columns='Medals',values='Count')
#The following code doesn't work due to duplicated values

# %%
tb2.groupby(['Country','Year','Medal']).Count.sum().unstack(-1,0)
#Doing the following using group by

# %%
#Using Pivot Table

# %%
tb2.pivot_table(index='Country',columns='Medal',values='Count',aggfunc='sum',margins=True).head()
#The following can also be done by groupby and unstack, only margins has to be donett Manually

# %%
#using pd.crosstab
t.head(2)

# %%
pd.crosstab(index=t.sex,columns=t.pclass)#Its forming relations between index and columns
#Can be used for multiple data frames simultaneously

# %%
pd.crosstab(index=t.sex,columns=t.pclass,values=t.fare,aggfunc='sum')
#Performing changes based on specific values

# %%
pd.crosstab(index=t.sex,columns=t.pclass,values=t.fare,aggfunc='sum',normalize=True,margins=True)
#additional functionality using normaling and margins

# %%
pd.crosstab(index=t.sex,columns=t.pclass,values=t.survived,aggfunc='mean',margins=True)

# %%
t.groupby(by=['sex','pclass']).survived.mean().unstack(-1)
#Similar results using groupby
#lacks margins and normalize and other addn functionality

# %%
olym=pd.read_csv('summer.csv')
olym.head(2)

# %%
pd.crosstab(index=[olym.Country,olym.Sport],columns=olym.Medal,margins=True)
#Using and exploring functionality

# %%
olym.groupby(['Country','Sport','Medal']).Medal.count().unstack(-1).fillna(0)
#We obtained the same table using groupby

# %%
olym=pd.read_csv('summer.csv')
olym.loc[::,'Winner/Loser']='loss'
olym.head(2)
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal Winner/Loser
# 0  100M Freestyle    Gold         loss
# 1  100M Freestyle  Silver         loss

# %%
olym.loc[olym.Medal=='Gold',['Winner/Loser']]='win'

# %%
olym1=olym.groupby(['Country','Sport','Medal']).Medal.count().unstack(-1,0)
olym1.loc[::,'Total']=(olym1.Bronze+olym1.Silver+olym1.Gold)
olym1
# Out:
# Medal                  Bronze  Gold  Silver  Total
# Country Sport
# AFG     Taekwondo           2     0       0      2
# AHO     Sailing             0     0       1      1
# ALG     Athletics           2     4       1      7
#         Boxing              5     1       0      6
#         Judo                1     0       1      2
# ANZ     Aquatics            3     5       3     11
#         Athletics           1     0       0      1
#         Boxing              0     0       1      1
#         Rugby               0    15       0     15
#         Tennis              1     0       0      1
# ARG     Aquatics            1     1       1      3
#         Athletics           0     2       3      5
#         Basketball         12    12       0     24
#         Boxing             10     7       7     24
#         Cycling             0     2       0      2
#         Equestrian          0     0       1      1
#         Fencing             5     0       0      5
# ...

# %%
olym2=olym.loc[olym.Athlete=='PHELPS, Michael']

# %%
olym2.groupby(['Year','Country','Sport']).Medal.count()
# Out:
# Year  Country  Sport
# 2004  USA      Aquatics    8
# 2008  USA      Aquatics    8
# 2012  USA      Aquatics    6
# Name: Medal, dtype: int64

# %%
(olym.groupby(['Country','Sport','Medal']).Medal.count()).to_frame()
# Out:
#                              Medal
# Country Sport        Medal
# AFG     Taekwondo    Bronze      2
# AHO     Sailing      Silver      1
# ALG     Athletics    Bronze      2
#                      Gold        4
#                      Silver      1
#         Boxing       Bronze      5
#                      Gold        1
#         Judo         Bronze      1
#                      Silver      1
# ANZ     Aquatics     Bronze      3
#                      Gold        5
#                      Silver      3
#         Athletics    Bronze      1
#         Boxing       Silver      1
#         Rugby        Gold       15
#         Tennis       Bronze      1
# ARG     Aquatics     Bronze      1
#                      Gold        1
#                      Silver      1
#         Athletics    Gold        2
#                      Silver      3
#         Basketball   Bronze     12
#                      Gold       12
#         Boxing       Bronze     10
#                      Gold        7
# ...
