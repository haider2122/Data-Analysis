# %%
import pandas as pd

# %%
t=pd.read_csv('titanic.csv')

# %%
age=t.loc[::,'age']
type(age)#Age here is a series
# Out:
# pandas.core.series.Series

# %%
#Certain methods and attributes work for both Dataframes and Series
#some methods only work for either one of them

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age.tail()
# Out:
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, dtype: float64

# %%
age.info#doest work for Series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a54cd0f65863> in <module>()
# ----> 1 age.info#doest work for Series
#
# C:\Users\Haider\Desktop\New folder\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
age.shape
# Out:
# (891,)

# %%
age.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
age.dtype
# Out:
# dtype('float64')

# %%
print(age.count())
len(age)
# Out:
# 714
# 891

# %%
print(age.sum())#exclude nan values
print(sum(age))#conside nan values
# Out:
# 21205.17
# nan

# %%
age.mean(skipna=False)
# Out:
# nan

# %%
age.median()
# Out:
# 28.0

# %%
age.std()
# Out:
# 14.526497332334044

# %%
age.ptp()#(max-min)
# Out:
# 79.579999999999998

# %%
age.unique()#only available for Series
# Out:
# array([ 22.  ,  38.  ,  26.  ,  35.  ,    nan,  54.  ,   2.  ,  27.  ,
#         14.  ,   4.  ,  58.  ,  20.  ,  39.  ,  55.  ,  31.  ,  34.  ,
#         15.  ,  28.  ,   8.  ,  19.  ,  40.  ,  66.  ,  42.  ,  21.  ,
#         18.  ,   3.  ,   7.  ,  49.  ,  29.  ,  65.  ,  28.5 ,   5.  ,
#         11.  ,  45.  ,  17.  ,  32.  ,  16.  ,  25.  ,   0.83,  30.  ,
#         33.  ,  23.  ,  24.  ,  46.  ,  59.  ,  71.  ,  37.  ,  47.  ,
#         14.5 ,  70.5 ,  32.5 ,  12.  ,   9.  ,  36.5 ,  51.  ,  55.5 ,
#         40.5 ,  44.  ,   1.  ,  61.  ,  56.  ,  50.  ,  36.  ,  45.5 ,
#         20.5 ,  62.  ,  41.  ,  52.  ,  63.  ,  23.5 ,   0.92,  43.  ,
#         60.  ,  10.  ,  64.  ,  13.  ,  48.  ,   0.75,  53.  ,  57.  ,
#         80.  ,  70.  ,  24.5 ,   6.  ,   0.67,  30.5 ,   0.42,  34.5 ,  74.  ])

# %%
age.nunique()#Count unique values
# Out:
# 88

# %%
age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
age.value_counts(normalize=False,sort=True,ascending=False,dropna=False)
# Out:
# NaN       177
#  24.00     30
#  22.00     27
#  18.00     26
#  28.00     25
#  19.00     25
#  30.00     25
#  21.00     24
#  25.00     23
#  36.00     22
#  29.00     20
#  32.00     18
#  26.00     18
#  35.00     18
#  27.00     18
#  16.00     17
#  31.00     17
#  34.00     15
#  23.00     15
#  33.00     15
#  20.00     15
#  39.00     14
#  17.00     13
#  42.00     13
#  40.00     13
#  45.00     12
#  38.00     11
#  50.00     10
#  2.00      10
#  4.00      10
#          ...
#  28.50      2
#  63.00      2
#  0.83       2
#  30.50      2
#  70.00      2
#  57.00      2
#  0.75       2
#  13.00      2
#  59.00      2
#  10.00      2
#  64.00      2
#  40.50      2
#  45.50      2
#  32.50      2
#  20.50      1
#  24.50      1
#  0.67       1
#  70.50      1
#  0.92       1
#  74.00      1
#  34.50      1
#  14.50      1
#  80.00      1
#  12.00      1
#  53.00      1
#  36.50      1
#  55.50      1
#  66.00      1
#  23.50      1
#  0.42       1
# ...

# %%
s=pd.read_csv('summer.csv',usecols=["Athlete"],squeeze=True)#directly obtaining a series
s
# Out:
# 0                            HAJOS, Alfred
# 1                         HERSCHMANN, Otto
# 2                        DRIVAS, Dimitrios
# 3                       MALOKINIS, Ioannis
# 4                       CHASAPIS, Spiridon
# 5                    CHOROPHAS, Efstathios
# 6                            HAJOS, Alfred
# 7                         ANDREOU, Joannis
# 8                    CHOROPHAS, Efstathios
# 9                            NEUMANN, Paul
# 10                       PEPANOS, Antonios
# 11                           LANE, Francis
# 12                        SZOKOLYI, Alajos
# 13                           BURKE, Thomas
# 14                          HOFMANN, Fritz
# 15                          CURTIS, Thomas
# 16                      GOULDING, Grantley
# 17                       LERMUSIAUX, Albin
# 18                            FLACK, Edwin
# 19                           BLAKE, Arthur
# 20                         GMELIN, Charles
# 21                           BURKE, Thomas
# ...

# %%
pd.Series([10,25,36])#Creating a series directly
# Out:
# 0    10
# 1    25
# 2    36
# dtype: int64

# %%
pd.Series([10,40,40],index=['mon','tue','wed'],name='money saved ')
# Out:
# mon    10
# tue    40
# wed    40
# Name: money saved , dtype: int64

# %%
a=[1,2,3,4]#converting a list to Series(we can also turn a tuple into series)
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
d={'onion':85,'potato':35,'beans':52}#Passing dict to series
ds=pd.Series(d)
ds
# Out:
# beans     52
# onion     85
# potato    35
# dtype: int64

# %%
da={0:2,1:4,2:5}

# %%
q=pd.Series(da)
q
# Out:
# 0    2
# 1    4
# 2    5
# dtype: int64

# %%
q.sort_index(ascending=False,inplace=True)#saves values or changes to q(initial series)

# %%
q
# Out:
# 2    5
# 1    4
# 0    2
# dtype: int64

# %%
q.sort_values(ascending=False)
# Out:
# 2    5
# 1    4
# 0    2
# dtype: int64

# %%
age.sort_values(ascending=False).iloc[:3,]#finding the smallest values
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# Name: age, dtype: float64

# %%
age.nlargest(3)#largest values, this equal the above opt with sort values and iloc
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# Name: age, dtype: float64

# %%
age.nsmallest(3)
# Out:
# 803    0.42
# 755    0.67
# 469    0.75
# Name: age, dtype: float64

# %%
age.sort_values().iloc[:1:].index[0]#Finding the index of the smallest values
# Out:
# 803

# %%
age.idxmin()#Does the same as above
# Out:
# 803

# %%
age.idxmax()#Finds index of largest value
# Out:
# 630

# %%
sales = pd.Series([10,25,6,36,2,0,None,5], index = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun", "Mon"])
sales
# Out:
# Mon    10.0
# Tue    25.0
# Wed     6.0
# Thu    36.0
# Fri     2.0
# Sat     0.0
# Sun     NaN
# Mon     5.0
# dtype: float64

# %%
sales.loc['Sun']=0#changing value to any component of a series

# %%
sales
# Out:
# Mon    10.0
# Tue    25.0
# Wed     6.0
# Thu    36.0
# Fri     2.0
# Sat     0.0
# Sun     0.0
# Mon     5.0
# dtype: float64

# %%
(sales/1.42).round(2)#performing opts on each values of sales Series
# Out:
# Mon     7.04
# Tue    17.61
# Wed     4.23
# Thu    25.35
# Fri     1.41
# Sat     0.00
# Sun     0.00
# Mon     3.52
# dtype: float64

# %%
age.iloc[2]=1#changing values of indx 2 of age series of titanic
# Out:
# C:\Users\Haider\Desktop\New folder\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
t.head(3)#But Value changes in data frame also
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female   1.0      0      0   7.9250        S  NaN

# %%
olym=pd.read_csv('summer.csv',index_col='Athlete')

# %%
olym
# Out:
#                                    Year    City      Sport  \
# Athlete
# HAJOS, Alfred                      1896  Athens   Aquatics
# HERSCHMANN, Otto                   1896  Athens   Aquatics
# DRIVAS, Dimitrios                  1896  Athens   Aquatics
# MALOKINIS, Ioannis                 1896  Athens   Aquatics
# CHASAPIS, Spiridon                 1896  Athens   Aquatics
# CHOROPHAS, Efstathios              1896  Athens   Aquatics
# HAJOS, Alfred                      1896  Athens   Aquatics
# ANDREOU, Joannis                   1896  Athens   Aquatics
# CHOROPHAS, Efstathios              1896  Athens   Aquatics
# NEUMANN, Paul                      1896  Athens   Aquatics
# PEPANOS, Antonios                  1896  Athens   Aquatics
# LANE, Francis                      1896  Athens  Athletics
# SZOKOLYI, Alajos                   1896  Athens  Athletics
# BURKE, Thomas                      1896  Athens  Athletics
# HOFMANN, Fritz                     1896  Athens  Athletics
# ...

# %%
olym.columns[:3]
# Out:
# Index(['Year', 'City', 'Sport'], dtype='object')

# %%
olym.index[:10].unique()
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'ANDREOU, Joannis', 'NEUMANN, Paul'],
#       dtype='object', name='Athlete')

# %%
olym.index[4]
# Out:
# 'CHASAPIS, Spiridon'

# %%
olym.index.get_loc('CHASAPIS, Spiridon')#getting loc of data or particular index
# Out:
# 4

# %%
olym.index.is_unique
# Out:
# False

# %%
a=pd.Index(['m','t','w'])#Creating an index

#Curve brackets for creating and square brackets for already existing Series/DF

# %%
pd.Series([10,40,70],index=a,name='Sales')
# Out:
# m    10
# t    40
# w    70
# Name: Sales, dtype: int64

# %%
olym.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
olym.reset_index()
# Out:
#                                  Athlete  Year    City      Sport  \
# 0                          HAJOS, Alfred  1896  Athens   Aquatics
# 1                       HERSCHMANN, Otto  1896  Athens   Aquatics
# 2                      DRIVAS, Dimitrios  1896  Athens   Aquatics
# 3                     MALOKINIS, Ioannis  1896  Athens   Aquatics
# 4                     CHASAPIS, Spiridon  1896  Athens   Aquatics
# 5                  CHOROPHAS, Efstathios  1896  Athens   Aquatics
# 6                          HAJOS, Alfred  1896  Athens   Aquatics
# 7                       ANDREOU, Joannis  1896  Athens   Aquatics
# 8                  CHOROPHAS, Efstathios  1896  Athens   Aquatics
# 9                          NEUMANN, Paul  1896  Athens   Aquatics
# 10                     PEPANOS, Antonios  1896  Athens   Aquatics
# 11                         LANE, Francis  1896  Athens  Athletics
# 12                      SZOKOLYI, Alajos  1896  Athens  Athletics
# ...

# %% [raw]
# olym.reset_index(drop=True)#will delete exixting index after reset

# %%
olym.set_index('Year')#set new index
# Out:
#         City      Sport           Discipline Country Gender  \
# Year
# 1896  Athens   Aquatics             Swimming     HUN    Men
# 1896  Athens   Aquatics             Swimming     AUT    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     HUN    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     AUT    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens  Athletics            Athletics     USA    Men
# 1896  Athens  Athletics            Athletics     HUN    Men
# 1896  Athens  Athletics            Athletics     USA    Men
# ...

# %%
olym.index[2]='ssd' #index is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-f92ba30ab970> in <module>()
# ----> 1 olym.index[2]='ssd' #index is immutable
#
# C:\Users\Haider\Desktop\New folder\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    2063
#    2064     def __setitem__(self, key, value):
# -> 2065         raise TypeError("Index does not support mutable operations")
#    2066
#    2067     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
n=olym.index.size
n
# Out:
# 31165

# %%
s=[]#Creating new index
for i in range(0,n):
    s.append('Medal No {}'.format(i))

# %%
olym.reset_index(drop=True).head(2)
# Out:
#    Year    City     Sport Discipline Country Gender           Event   Medal
# 0  1896  Athens  Aquatics   Swimming     HUN    Men  100M Freestyle    Gold
# 1  1896  Athens  Aquatics   Swimming     AUT    Men  100M Freestyle  Silver

# %%
olym.set_index=s#Created index s is saved as new inde

# %%
olym.head(2)
# Out:
#                   Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred     1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT    Men
#
#                            Event   Medal
# Athlete
# HAJOS, Alfred     100M Freestyle    Gold
# HERSCHMANN, Otto  100M Freestyle  Silver

# %%
olym.index.name='Medal no'#Giving our index a name
olym.head(1)
# Out:
#                Year    City     Sport Discipline Country Gender  \
# Medal no
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
#                         Event Medal
# Medal no
# HAJOS, Alfred  100M Freestyle  Gold

# %% [raw]
# Columns are also immutable

# %%
olym.columns.name='Info'#Setting new name for column

# %%
olym.head(1)
# Out:
# Info           Year    City     Sport Discipline Country Gender  \
# Medal no
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
# Info                    Event Medal
# Medal no
# HAJOS, Alfred  100M Freestyle  Gold

# %%
olym.set_index=s
olym
# Out:
# Info                               Year    City      Sport  \
# Medal no
# HAJOS, Alfred                      1896  Athens   Aquatics
# HERSCHMANN, Otto                   1896  Athens   Aquatics
# DRIVAS, Dimitrios                  1896  Athens   Aquatics
# MALOKINIS, Ioannis                 1896  Athens   Aquatics
# CHASAPIS, Spiridon                 1896  Athens   Aquatics
# CHOROPHAS, Efstathios              1896  Athens   Aquatics
# HAJOS, Alfred                      1896  Athens   Aquatics
# ANDREOU, Joannis                   1896  Athens   Aquatics
# CHOROPHAS, Efstathios              1896  Athens   Aquatics
# NEUMANN, Paul                      1896  Athens   Aquatics
# PEPANOS, Antonios                  1896  Athens   Aquatics
# LANE, Francis                      1896  Athens  Athletics
# SZOKOLYI, Alajos                   1896  Athens  Athletics
# BURKE, Thomas                      1896  Athens  Athletics
# HOFMANN, Fritz                     1896  Athens  Athletics
# ...

# %%
tt=pd.read_csv('titanic.csv')
tt.reset_index(inplace=True,drop=True)
